# %%
import matplotlib.pyplot as plt

plt.plot(data1, "--g")
plt.plot(data2, "y")
print('Statistics=%.3f, p=%.3f' % (stat, p))
# Out:
# Statistics=56.000, p=0.067

# %%
from scipy.stats import wilcoxon
data1 = 0.1, 0.5, 0.7, 1.9, 0.8, 0.5, 0.1, 1.5, 3.4, 2.8, 6.5, 1.4, 2.9, 2, 6.4, 1.4, 3.2, 2.6, 6.1, 0.3
data2 = 3.16, 4.01, 4.04, 1.11, 1.97, 1.46, 1.45, 2.71, 3.66, 3.28, 3.24, 2.76, 3.83, 3.31, 4.11, 3.51, 3.84, 3.22, 3.16, 0.17

stat, p = wilcoxon(data1, data2)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=56.000, p=0.067
# Same distribution (fail to reject H0)

# %%
import numpy as np

plt.scatter(data1, data2)
trendline(data1, data2)
#plt.scatter(data2)
print('Statistics=%.3f, p=%.3f' % (stat, p))

print("Correlation Coefficient = " + str(np.corrcoef(data1, data2)[0,1]))
# Out:
# Statistics=56.000, p=0.067
# Correlation Coefficient = 0.4320543525436342

# %%
def trendline(xd, yd, order=1, c='--r', alpha=1, Rval=False):
    """Make a line of best fit"""

    #Calculate trendline
    coeffs = np.polyfit(xd, yd, order)

    intercept = coeffs[-1]
    slope = coeffs[-2]
    power = coeffs[0] if order == 2 else 0

    minxd = np.min(xd)
    maxxd = np.max(xd)

    xl = np.array([minxd, maxxd])
    yl = power * xl ** 2 + slope * xl + intercept

    #Plot trendline
    plt.plot(xl, yl, c, alpha=alpha)
