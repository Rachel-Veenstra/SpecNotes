# %%
import glob
import pandas as pd
import numpy
import matplotlib.pylab as plt

path = str(glob.os.getcwd())

user = path.split('\\')[2]

folder = 'Ureides'

data_file_u = '/Users/' + user + '/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/' + folder

glob.os.chdir(data_file_u)

AllUfiles = glob.glob(data_file_u + "/*.csv")

Concentration_u = []

Sample_u = []

columns_u = ['ID_u', 'Concentration_u']
Ureide_final = pd.DataFrame(columns=columns_u)

for file in AllUfiles:
    ur_df = pd.read_csv(file, header=0)
    ur_df.rename(columns = {'Sample Name':'ID', '535 nm   [A]':'B'}, inplace=True)
    
    ur_df = ur_df[['ID', 'B']]
    
    ur_g = ur_df.groupby('ID')

    ur_final=ur_df.merge(ur_g.mean(),on='ID')
    ur_final2=ur_final.merge(abs(ur_g.max()-ur_g.min())/ur_g.max(), on='ID')
    ur_final2.rename(columns = {'B':'Var', 'B_x':'Abs', 'B_y':'Mean'}, inplace=True)

    c_u = (0,0,0,549.6,549.6,549.6,1099.2,1099.2,1099.2,4396.7,4396.7,4396.7)
    a_u = ur_final2.iloc[4:16, 1]
    m_u = ur_final2.iloc[4:16, 2]

    ur_curve_val = ur_df.iloc[4:16, 0]
    
   ## CREATING CONDITIONAL TO FILTER OUT BAD CURVES AND NOT RUN THEM!!

    ur_curve_var = ur_final2.iloc[4:16, 3]
    
    if float(ur_curve_var.all()) > 0.10:
        print(file)
        print("Error: Calibration Data Unreliable")
        
    ############################################################

    else:
        try:
            float(ur_curve_val[0:2].all()) == 0.00
            float(ur_curve_val[3:5].all()) == 549.58
            float(ur_curve_val[6:8].all()) == 1099.17
            float(ur_curve_val[9:11].all()) == 4396.66
    
            try:
                plt.plot(c_u, a_u, "ro")
                plt.plot(c_u, m_u,'bx')
                plt.ylabel("Absorbance Value")
                plt.xlabel("Concentration ppm")

                z_u = numpy.polyfit(c_u, m_u, 1, rcond=None, full=False, w=None, cov=False)
                p_u = numpy.poly1d(z_u)
                plt.plot(c_u, p_u(c_u),"g--")
                print("Ureide Calibration Curve")
                print(file)
                plt.show()
                print("absorbance = %.6f(concentration) + %.6f"%(z_u[0],z_u[1]))
                print("concentration = (absorbance - %.6f) / %.6f"%(z_u[1],z_u[0]))

                x_u=z_u[1]
                y_u=z_u[0]           

                for key, row in ur_final2.iterrows():
                    if float(row['Var']) > 0.1:
                        Concentration_u.append('Error')
                    else:
                        Concentration_u.append(((float(row['Mean'])-x_u)/y_u).round(3))
                
                    Sample_u.append(row['ID'])
            except:
                continue
        except:
            print(file)
            print("Error: Curve not identified.")
        
Ureide_final['Concentration_u'] = Concentration_u
Ureide_final['ID_u'] = Sample_u
Ureide_final
# Out:
# Ureide Calibration Curve
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LI FG Missed samples12-07-18.csv
# absorbance = 0.000623(concentration) + 0.019132
# concentration = (absorbance - 0.019132) / 0.000623
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ashland 11-15-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ashland 11-16-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ashland 11-19-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ashland 11-20-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ashland 11-21-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ashland Rep Ure 12-10-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Missed samples 12-05-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ottawa 11-26-18 (no curve).csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ottawa 11-26-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ottawa 11-27-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ottawa 11-28-18 b.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ottawa 11-28-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ottawa Rep Ur 12-11-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Ottawa Rep Ur 12-12-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIF Rep Ur LI-260 1-29-19.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIG 10-1-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIG 10-2-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIG 10-3-18 Rep.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\LIG 2-10-18 Set 2.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\Test 1 sample 2-13-19.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\Vitor greenhouse 10-24-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\Vitor greenhouse 10-26-18.csv
# Error: Calibration Data Unreliable
# Ureide Calibration Curve
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\Vitor greenhouse 10-26-18b.csv
# absorbance = 0.000539(concentration) + 0.015750
# concentration = (absorbance - 0.015750) / 0.000539
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\Vitor greenhouse 10-29-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\Vitor greenhouse 10-30-18.csv
# Error: Calibration Data Unreliable
# Ureide Calibration Curve
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\Vitor greenhouse 10-30-18b.csv
# absorbance = 0.000612(concentration) + 0.016655
# concentration = (absorbance - 0.016655) / 0.000612
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\Vitor greenhouse 11-01-18.csv
# Error: Calibration Data Unreliable
# /Users/rveenstra/Dropbox/CropProdLabKSU/Lab Analysis/VISIONlite Results/Ureides\Vitor greenhouse 11-01-18b.csv
# Error: Calibration Data Unreliable
#             ID_u Concentration_u
# 0            1_1         -14.654
# 1            1_2         -13.049
# 2            2_1           -9.84
# 3            2_2         -13.049
# 4           0.00         -17.863
# 5           0.00         -17.863
# 6           0.00         -17.863
# 7    549.5825955         565.162
# 8    549.5825955         565.162
# 9    549.5825955         565.162
# 10   1099.165191         1104.86
# 11   1099.165191         1104.86
# 12   1099.165191         1104.86
# 13   4396.660764         4393.34
# 14   4396.660764         4393.34
# 15   4396.660764         4393.34
# 16       LIG-359         2088.25
# 17       LIG-359         2088.25
# 18       LIG-360         3151.34
# 19       LIG-360         3151.34
# 20       LIF-226         178.707
# 21       LIF-226         178.707
# 22       LIF-231         201.172
# 23       LIF-231         201.172
# 24       LIF-232          1001.9
# 25       LIF-232          1001.9
# 26       LIF-233           141.8
# 27       LIF-233           141.8
# 28       LIF-234         162.661
# 29       LIF-234         162.661
# ..           ...             ...
# 106         0.00         -12.505
# 107         0.00         -12.505
# 108         0.00         -12.505
# 109  549.5825955         551.088
# 110  549.5825955         551.088
# 111  549.5825955         551.088
# 112  1099.165191         1114.14
# 113  1099.165191         1114.14
# 114  1099.165191         1114.14
# 115  4396.660764         4392.78
# 116  4396.660764         4392.78
# 117  4396.660764         4392.78
# 118        VG-01           Error
# 119        VG-01           Error
# 120        VG-02           98.58
# 121        VG-02           98.58
# 122        VG-04         105.115
# 123        VG-04         105.115
# 124        VG-06          56.106
# 125        VG-06          56.106
# 126        VG-07          32.419
# 127        VG-07          32.419
# 128        VG-74         109.199
# 129        VG-74         109.199
# 130        VG-87         123.901
# 131        VG-87         123.901
# 132        VG-93         645.021
# 133        VG-93         645.021
# 134        VG-94         1200.45
# 135        VG-94         1200.45
#
# [136 rows x 2 columns]

# %%
ur_final2
# Out:
#              ID    Abs      Mean       Var
# 0           1_1  0.012  0.012000  0.000000
# 1           1_2  0.012  0.012000  0.000000
# 2           2_1  0.000  0.000000       NaN
# 3           2_2  0.000  0.000000       NaN
# 4          0.00  0.011  0.010333  0.090909
# 5          0.00  0.010  0.010333  0.090909
# 6          0.00  0.010  0.010333  0.090909
# 7   549.5825955  0.358  0.362667  0.029810
# 8   549.5825955  0.361  0.362667  0.029810
# 9   549.5825955  0.369  0.362667  0.029810
# 10  1099.165191  0.702  0.702000  0.025316
# 11  1099.165191  0.693  0.702000  0.025316
# 12  1099.165191  0.711  0.702000  0.025316
# 13  4396.660764  2.665  2.681000  0.011132
# 14  4396.660764  2.683  2.681000  0.011132
# 15  4396.660764  2.695  2.681000  0.011132
# 16        VG-01  0.094  0.085000  0.191489
# 17        VG-01  0.076  0.085000  0.191489
# 18        VG-02  0.102  0.102000  0.000000
# 19        VG-02  0.102  0.102000  0.000000
# 20        VG-04  0.083  0.080000  0.072289
# 21        VG-04  0.077  0.080000  0.072289
# 22        VG-06  0.073  0.070000  0.082192
# 23        VG-06  0.067  0.070000  0.082192
# 24        VG-07  0.067  0.070000  0.082192
# 25        VG-07  0.073  0.070000  0.082192
# 26        VG-74  0.073  0.037500  0.972603
# 27        VG-74  0.002  0.037500  0.972603
# 28        VG-87  0.001  0.001000  0.000000
# 29        VG-87  0.001  0.001000  0.000000
